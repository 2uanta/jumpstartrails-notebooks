# %% [markdown]
# ### Partial templates or Partials

# %% [markdown]
# ### Create a new folder app/views/partials

# %% [markdown]
# ### Create a subdirectory called _twitter.html.erb

# %% [markdown]
# ### Go create and download a twitter widget at http://twitter.com/settings/widget/new

# %% [markdown]
# ### add the widget in app/views/pages/about.html.erb

# %% [raw]
# <p><%= @page.content.html_safe %></p>
# <div class="row">
#   <div class="span9 offset3">
#   	<h2>Send us a message</h2>
#   </div>
# </div>
#
# <div class="row-fluid">
#   <div class="span8">
#   	form here
#   </div>
#   <div class="span4"><%= render 'partials/twitter' %>/div>
# </div>
#
# <div class="row">
#   <div class="span9 offset2">
#     <h3>About Jump Start Rails</h3>
#   </div>
# </div>
# <div class="row-fluid">
#   <div class="span8">
#   	"Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat. Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur. Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum."
#   </div>
# </div>

# %% [markdown]
# ## CoffeesScript

# %% [markdown]
# ### add to app/assets/javascripts/post.js.coffee

# %% [raw]
# # Place all the behaviors and hooks related to the matching controller here.
# # All this logic will automatically be available in application.js.
# # You can use CoffeeScript in this file: http://coffeescript.org/
#
# $(document).ready ->
#   $('#test_click').click (e) ->
#     do notify
#
#   notify = -> alert('Hello!')
#
#   $(".blurb_content").hide()
#   $('.blurb_target').click (e) ->
#     $(this).parent().next(".blurb_content").toggle(400)
#     return false

# %% [markdown]
# ### add matching class in apps/views/posts/index.html.erb

# %% [raw]
# table class="table table-bordered">
#   <% @posts.each do |post| %>
#   <tr>
#     <td style="width:100px;"><%= image_tag post.image_url(:thumb).to_s %></td>
#       <td>
#         <div>
#           <strong><%= post.title %></strong><br />
#             <p class="blurb_target">
#               <a href="#">Show/hide blurb</a>
#             </p>
#          </div>
#          <p class="blurb_content"><%= post.blurb %></p>
#          <%= link_to 'Read Post', post %>
#       </td>
#     </tr>
#   <% end %>
# </table>
# <a href="#" id="test_click">Just testing</a>

# %% [markdown]
# ## Watch out for those Turbolinks

# %% [markdown]
# ### Add the 'jquery.turbolinks' to the Gemfile and add the asset in app/assets/javascripts/application.js

# %% [markdown]
# ## Adding the Portfolio (or Other Content) Section

# %% [markdown]
# ### app/controllers/pages_controller.rb

# %% [raw]
# class PagesController < ApplicationController
#   def index
#   	@pages = Page.find(1)
#   end
#
#   def about
#   	@page = Page.where(slug: 'about').first
#   end
#
#   def contact
#   end
#
#   def portfolio
#   end
# end

# %% [markdown]
# ### add portfolio link in app/views/layouts/pages.html.erb and posts.html.erb

# %% [raw]
#                 <%= nav_link 'Home', root_path %>
#                 <%= nav_link 'About', about_path %>
#                 <%= nav_link 'Portfolio', portfolio_path %>
#                 <%= nav_link 'Blog', posts_path %>

# %% [markdown]
# ### Add portfolio path in routes.db

# %% [raw]
#   %w[about contact portfolio cv].each do |page|
#     get page, controller: 'pages', action: page
#   end

# %% [markdown]
# ### create app/views/pages/portfolio.html.erb

# %% [raw]
# <div class="row">
#   <div class="span5" style="font-size: 12px;">
#     <div id="tabs">
#       <ul>
#         <li><a href="#tabs-1">Nunc tincidunt</a></li>
#         <li><a href="#tabs-2">Proin dolor</a></li>
#         <li><a href="#tabs-3">Aenean lacinia</a></li>
#       </ul>
#       <div id="tabs-1">
#         <p>Tab content.</p>
#       </div>
#       <div id="tabs-2">
#         <p>Tab content.</p>
#       </div>
#       <div id="tabs-3">
#         <p>Tab content</p>
#       </div>
#     </div>
#   </div>
#   <div class="span4">
#     content here
#   </div>
# </div>

# %% [markdown]
# ### add jquery-ui stylesheer to app/views/layouts/pages and posts.html.erb

# %% [raw]
# <link rel="stylesheet" href="http://code.jquery.com/ui/1.10.2/themes/smoothness/jquery-ui.css"/>

# %% [markdown]
# ### add coffeescript code for the tabs function in app/assets/javascripts/pages.js.coffee

# %% [raw]
# $ -> $("#tabs").tabs()

# %% [markdown]
# # Heroku

# %% [markdown]
# ### Generate ssh keys as per https://help.github.com/articles/generating-ssh-keys

# %% [raw]
# Install ssh key as per http://stackoverflow.com/questions/9560892/permissions-error-github-ssh-key-not-recognized and https://devcenter.heroku.com/articles/keys

# %% [raw]
# quan@quan-VirtualBox:~$ ssh-keygen -t rsa -C 'mr.quan.nguyen@gmail.com'
# Generating public/private rsa key pair.
# Enter file in which to save the key (/home/quan/.ssh/id_rsa):
# Enter passphrase (empty for no passphrase):
# Enter same passphrase again:
# Your identification has been saved in /home/quan/.ssh/id_rsa.
# Your public key has been saved in /home/quan/.ssh/id_rsa.pub.
# The key fingerprint is:
# 92:4e:ff:dc:5e:47:88:28:94:b8:8b:1e:ca:7a:71:57 mr.quan.nguyen@gmail.com
# The key's randomart image is:
# +--[ RSA 2048]----+
# |                 |
# |       . .       |
# |      . o        |
# |       +E  . . . |
# |      =.S . . . .|
# |  . .+.+ .     . |
# |   oo.o .     . .|
# | ..o .   o . . . |
# |.oo .     o.o    |
# +-----------------+
#
# quan@quan-VirtualBox:~$ sudo apt-get install xclip
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following NEW packages will be installed:
#   xclip
# 0 upgraded, 1 newly installed, 0 to remove and 50 not upgraded.
# Need to get 19.7 kB of archives.
# After this operation, 94.2 kB of additional disk space will be used.
# Get:1 http://ca.archive.ubuntu.com/ubuntu/ precise/universe xclip i386 0.12-1 [19.7 kB]
# Fetched 19.7 kB in 0s (58.0 kB/s)
# Selecting previously unselected package xclip.
# (Reading database ... 248919 files and directories currently installed.)
# Unpacking xclip (from .../archives/xclip_0.12-1_i386.deb) ...
# Processing triggers for man-db ...
# Setting up xclip (0.12-1) ...
#
# quan@quan-VirtualBox:~$ xclip -sel clip < ~/.ssh/id_rsa.pub

# %% [raw]
# quan@quan-VirtualBox:~$ wget -qO- https://toolbelt.heroku.com/install-ubuntu.sh | sh
# This script requires superuser access to install apt packages.
# You will be prompted for your password by sudo.
# [sudo] password for quan:
# --2013-09-19 22:50:59--  https://toolbelt.heroku.com/apt/release.key
# Resolving toolbelt.heroku.com (toolbelt.heroku.com)... 174.129.23.129, 50.16.215.20, 50.16.215.67, ...
# Connecting to toolbelt.heroku.com (toolbelt.heroku.com)|174.129.23.129|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1737 (1.7K) [application/octet-stream]
# Saving to: `STDOUT'
#
# 100%[======================================>] 1,737       --.-K/s   in 0s
#
# 2013-09-19 22:51:00 (396 MB/s) - written to stdout [1737/1737]
#
# OK
# Get:1 http://security.ubuntu.com precise-security Release.gpg [198 B]
# Get:2 http://dl.google.com stable Release.gpg [198 B]
# Get:3 http://security.ubuntu.com precise-security Release [49.6 kB]
# Get:4 http://dl.google.com stable Release [1,347 B]
# Get:5 http://dl.google.com stable/main i386 Packages [1,219 B]
# Get:6 http://toolbelt.heroku.com ./ Release.gpg [490 B]
# Get:7 http://security.ubuntu.com precise-security/main Sources [88.1 kB]
# Hit http://ca.archive.ubuntu.com precise Release.gpg
# Get:8 http://ca.archive.ubuntu.com precise-updates Release.gpg [198 B]
# Hit http://ca.archive.ubuntu.com precise-backports Release.gpg
# Ign http://dl.google.com stable/main TranslationIndex
# Get:9 http://extras.ubuntu.com precise Release.gpg [72 B]
# Hit http://ca.archive.ubuntu.com precise Release
# Get:10 http://ca.archive.ubuntu.com precise-updates Release [49.6 kB]
# Get:11 http://toolbelt.heroku.com ./ Release [1,673 B]
# Hit http://extras.ubuntu.com precise Release
# Get:12 http://security.ubuntu.com precise-security/restricted Sources [2,494 B]
# Get:13 http://security.ubuntu.com precise-security/universe Sources [28.0 kB]
# Get:14 http://security.ubuntu.com precise-security/multiverse Sources [1,804 B]
# Get:15 http://security.ubuntu.com precise-security/main i386 Packages [337 kB]
# Get:16 http://toolbelt.heroku.com ./ Packages [1,042 B]
# Hit http://extras.ubuntu.com precise/main Sources
# Ign http://dl.google.com stable/main Translation-en_CA
# Hit http://ca.archive.ubuntu.com precise-backports Release
# Ign http://dl.google.com stable/main Translation-en
# Hit http://extras.ubuntu.com precise/main i386 Packages
# Ign http://extras.ubuntu.com precise/main TranslationIndex
# Hit http://ca.archive.ubuntu.com precise/main Sources
# Hit http://ca.archive.ubuntu.com precise/restricted Sources
# Hit http://ca.archive.ubuntu.com precise/universe Sources
# Hit http://ca.archive.ubuntu.com precise/multiverse Sources
# Hit http://ca.archive.ubuntu.com precise/main i386 Packages
# Hit http://ca.archive.ubuntu.com precise/restricted i386 Packages
# Hit http://ca.archive.ubuntu.com precise/universe i386 Packages
# Hit http://ca.archive.ubuntu.com precise/multiverse i386 Packages
# Hit http://ca.archive.ubuntu.com precise/main TranslationIndex
# Hit http://ca.archive.ubuntu.com precise/multiverse TranslationIndex
# Hit http://ca.archive.ubuntu.com precise/restricted TranslationIndex
# Hit http://ca.archive.ubuntu.com precise/universe TranslationIndex
# Get:17 http://ca.archive.ubuntu.com precise-updates/main Sources [418 kB]
# Get:18 http://security.ubuntu.com precise-security/restricted i386 Packages [4,620 B]
# Get:19 http://security.ubuntu.com precise-security/universe i386 Packages [85.5 kB]
# Get:20 http://security.ubuntu.com precise-security/multiverse i386 Packages [2,640 B]
# Hit http://security.ubuntu.com precise-security/main TranslationIndex
# Hit http://security.ubuntu.com precise-security/multiverse TranslationIndex
# Hit http://security.ubuntu.com precise-security/restricted TranslationIndex
# Hit http://security.ubuntu.com precise-security/universe TranslationIndex
# Hit http://security.ubuntu.com precise-security/main Translation-en
# Hit http://security.ubuntu.com precise-security/multiverse Translation-en
# Hit http://security.ubuntu.com precise-security/restricted Translation-en
# Hit http://security.ubuntu.com precise-security/universe Translation-en
# Ign http://extras.ubuntu.com precise/main Translation-en_CA
# Ign http://extras.ubuntu.com precise/main Translation-en
# Ign http://toolbelt.heroku.com ./ Translation-en_CA
# Ign http://toolbelt.heroku.com ./ Translation-en
# Get:21 http://ca.archive.ubuntu.com precise-updates/restricted Sources [7,031 B]
# Get:22 http://ca.archive.ubuntu.com precise-updates/universe Sources [95.6 kB]
# Get:23 http://ca.archive.ubuntu.com precise-updates/multiverse Sources [8,343 B]
# Get:24 http://ca.archive.ubuntu.com precise-updates/main i386 Packages [708 kB]
# Get:25 http://ca.archive.ubuntu.com precise-updates/restricted i386 Packages [11.4 kB]
# Get:26 http://ca.archive.ubuntu.com precise-updates/universe i386 Packages [220 kB]
# Get:27 http://ca.archive.ubuntu.com precise-updates/multiverse i386 Packages [14.0 kB]
# Get:28 http://ca.archive.ubuntu.com precise-updates/main TranslationIndex [3,564 B]
# Get:29 http://ca.archive.ubuntu.com precise-updates/multiverse TranslationIndex [2,605 B]
# Get:30 http://ca.archive.ubuntu.com precise-updates/restricted TranslationIndex [2,461 B]
# Get:31 http://ca.archive.ubuntu.com precise-updates/universe TranslationIndex [2,850 B]
# Hit http://ca.archive.ubuntu.com precise-backports/main Sources
# Hit http://ca.archive.ubuntu.com precise-backports/restricted Sources
# Hit http://ca.archive.ubuntu.com precise-backports/universe Sources
# Hit http://ca.archive.ubuntu.com precise-backports/multiverse Sources
# Hit http://ca.archive.ubuntu.com precise-backports/main i386 Packages
# Hit http://ca.archive.ubuntu.com precise-backports/restricted i386 Packages
# Hit http://ca.archive.ubuntu.com precise-backports/universe i386 Packages
# Hit http://ca.archive.ubuntu.com precise-backports/multiverse i386 Packages
# Hit http://ca.archive.ubuntu.com precise-backports/main TranslationIndex
# Hit http://ca.archive.ubuntu.com precise-backports/multiverse TranslationIndex
# Hit http://ca.archive.ubuntu.com precise-backports/restricted TranslationIndex
# Hit http://ca.archive.ubuntu.com precise-backports/universe TranslationIndex
# Hit http://ca.archive.ubuntu.com precise/main Translation-en_CA
# Hit http://ca.archive.ubuntu.com precise/main Translation-en
# Hit http://ca.archive.ubuntu.com precise/multiverse Translation-en
# Hit http://ca.archive.ubuntu.com precise/restricted Translation-en
# Hit http://ca.archive.ubuntu.com precise/universe Translation-en_CA
# Hit http://ca.archive.ubuntu.com precise/universe Translation-en
# Hit http://ca.archive.ubuntu.com precise-updates/main Translation-en_CA
# Hit http://ca.archive.ubuntu.com precise-updates/main Translation-en
# Hit http://ca.archive.ubuntu.com precise-updates/multiverse Translation-en
# Hit http://ca.archive.ubuntu.com precise-updates/restricted Translation-en
# Hit http://ca.archive.ubuntu.com precise-updates/universe Translation-en_CA
# Hit http://ca.archive.ubuntu.com precise-updates/universe Translation-en
# Hit http://ca.archive.ubuntu.com precise-backports/main Translation-en
# Hit http://ca.archive.ubuntu.com precise-backports/multiverse Translation-en
# Hit http://ca.archive.ubuntu.com precise-backports/restricted Translation-en
# Hit http://ca.archive.ubuntu.com precise-backports/universe Translation-en
# Fetched 2,149 kB in 6s (346 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following extra packages will be installed:
#   foreman heroku libruby1.9.1 ruby1.9.1
# Suggested packages:
#   ruby1.9.1-examples ri1.9.1 graphviz ruby1.9.1-dev
# The following NEW packages will be installed:
#   foreman heroku heroku-toolbelt libruby1.9.1 ruby1.9.1
# 0 upgraded, 5 newly installed, 0 to remove and 50 not upgraded.
# Need to get 5,001 kB of archives.
# After this operation, 13.1 MB of additional disk space will be used.
# Get:1 http://ca.archive.ubuntu.com/ubuntu/ precise-updates/main libruby1.9.1 i386 1.9.3.0-1ubuntu2.7 [4,209 kB]
# Get:2 http://toolbelt.heroku.com/ubuntu/ ./ foreman 0.60.0 [89.5 kB]
# Get:3 http://toolbelt.heroku.com/ubuntu/ ./ heroku 2.41.0 [665 kB]
# Get:4 http://toolbelt.heroku.com/ubuntu/ ./ heroku-toolbelt 2.41.0 [626 B]
# Get:5 http://ca.archive.ubuntu.com/ubuntu/ precise-updates/main ruby1.9.1 i386 1.9.3.0-1ubuntu2.7 [37.0 kB]
# Fetched 5,001 kB in 11s (449 kB/s)
# Selecting previously unselected package libruby1.9.1.
# (Reading database ... 247437 files and directories currently installed.)
# Unpacking libruby1.9.1 (from .../libruby1.9.1_1.9.3.0-1ubuntu2.7_i386.deb) ...
# Selecting previously unselected package ruby1.9.1.
# Unpacking ruby1.9.1 (from .../ruby1.9.1_1.9.3.0-1ubuntu2.7_i386.deb) ...
# Selecting previously unselected package foreman.
# Unpacking foreman (from .../foreman_0.60.0_all.deb) ...
# Selecting previously unselected package heroku.
# Unpacking heroku (from .../archives/heroku_2.41.0_all.deb) ...
# Selecting previously unselected package heroku-toolbelt.
# Unpacking heroku-toolbelt (from .../heroku-toolbelt_2.41.0_all.deb) ...
# Processing triggers for man-db ...
# Setting up libruby1.9.1 (1.9.3.0-1ubuntu2.7) ...
# Setting up ruby1.9.1 (1.9.3.0-1ubuntu2.7) ...
# update-alternatives: using /usr/bin/gem1.9.1 to provide /usr/bin/gem (gem) in auto mode.
# update-alternatives: using /usr/bin/ruby1.9.1 to provide /usr/bin/ruby (ruby) in auto mode.
# Setting up foreman (0.60.0) ...
# Setting up heroku (2.41.0) ...
# Setting up heroku-toolbelt (2.41.0) ...
# Processing triggers for libc-bin ...
# ldconfig deferred processing now taking place

# %% [markdown]
# ### $ heroku login

# %% [raw]
# quan@quan-VirtualBox:~$ heroku login
# Enter your Heroku credentials.
# Email: mr.quan.nguyen@gmail.com
# Password (typing will be hidden):
# Authentication successful.
# quan@quan-VirtualBox:~$ cd rails_projects/jumpstartrails/

# %% [markdown]
# ### $ git init

# %% [raw]
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$ git init
# Initialized empty Git repository in /home/quan/rails_projects/jumpstartrails/.git/

# %% [markdown]
# ### $ git add .

# %% [raw]
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$ git add .

# %% [markdown]
# ### $ git commit -am 'first commit'

# %% [raw]
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$ git commit -am 'first commit'
# [master (root-commit) 2c938a3] first commit
#  Committer: Quan Nguyen <quan@quan-VirtualBox.(none)>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly:
#
#     git config --global user.name "Your Name"
#     git config --global user.email you@example.com
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author
#
#  107 files changed, 2539 insertions(+)
#  create mode 100644 .gitignore
#  create mode 100644 .rvmrc
#  create mode 100644 Gemfile
#  create mode 100644 Gemfile.lock
#  create mode 100644 README.rdoc
#  create mode 100644 Rakefile
#  create mode 100644 app/admin/admin_user.rb
#  create mode 100644 app/admin/category.rb
#  create mode 100644 app/admin/dashboard.rb
#  create mode 100644 app/admin/page.rb
#  create mode 100644 app/admin/post.rb
#  create mode 100644 app/assets/images/.keep
#  create mode 100644 app/assets/javascripts/active_admin.js.coffee
#  create mode 100644 app/assets/javascripts/application.js
#  create mode 100644 app/assets/javascripts/pages.js.coffee
#  create mode 100644 app/assets/javascripts/posts.js.coffee
#  create mode 100644 app/assets/stylesheets/active_admin.css.scss
#  create mode 100644 app/assets/stylesheets/application.css
#  create mode 100644 app/assets/stylesheets/pages.css.scss
#  create mode 100644 app/assets/stylesheets/posts.css.scss
#  create mode 100644 app/controllers/application_controller.rb
#  create mode 100644 app/controllers/concerns/.keep
#  create mode 100644 app/controllers/pages_controller.rb
#  create mode 100644 app/controllers/posts_controller.rb
#  create mode 100644 app/helpers/application_helper.rb
#  create mode 100644 app/helpers/pages_helper.rb
#  create mode 100644 app/helpers/posts_helper.rb
#  create mode 100644 app/mailers/.keep
#  create mode 100644 app/models/.keep
#  create mode 100644 app/models/admin_user.rb
#  create mode 100644 app/models/category.rb
#  create mode 100644 app/models/concerns/.keep
#  create mode 100644 app/models/page.rb
#  create mode 100644 app/models/post.rb
#  create mode 100644 app/uploaders/image_uploader.rb
#  create mode 100644 app/views/layouts/application.html.erb
#  create mode 100644 app/views/layouts/pages.html.erb
#  create mode 100644 app/views/layouts/posts.html.erb
#  create mode 100644 app/views/pages/about.html.erb
#  create mode 100644 app/views/pages/index.html.erb
#  create mode 100644 app/views/pages/portfolio.html.erb
#  create mode 100644 app/views/partials/_twitter.html.erb
#  create mode 100644 app/views/posts/index.html.erb
#  create mode 100644 app/views/posts/show.html.erb
#  create mode 100755 bin/bundle
#  create mode 100755 bin/rails
#  create mode 100755 bin/rake
#  create mode 100644 config.ru
#  create mode 100644 config/application.rb
#  create mode 100644 config/boot.rb
#  create mode 100644 config/database.yml
#  create mode 100644 config/environment.rb
#  create mode 100644 config/environments/development.rb
#  create mode 100644 config/environments/production.rb
#  create mode 100644 config/environments/test.rb
#  create mode 100644 config/initializers/active_admin.rb
#  create mode 100644 config/initializers/backtrace_silencers.rb
#  create mode 100644 config/initializers/carrierwave.rb
#  create mode 100644 config/initializers/devise.rb
#  create mode 100644 config/initializers/filter_parameter_logging.rb
#  create mode 100644 config/initializers/inflections.rb
#  create mode 100644 config/initializers/mime_types.rb
#  create mode 100644 config/initializers/secret_token.rb
#  create mode 100644 config/initializers/session_store.rb
#  create mode 100644 config/initializers/wrap_parameters.rb
#  create mode 100644 config/locales/devise.en.yml
#  create mode 100644 config/locales/en.yml
#  create mode 100644 config/routes.rb
#  create mode 100644 db/migrate/20130918131249_create_pages.rb
#  create mode 100644 db/migrate/20130919131322_add_slug_to_pages.rb
#  create mode 100644 db/migrate/20130919131323_create_categories.rb
#  create mode 100644 db/migrate/20130919131324_create_posts.rb
#  create mode 100644 db/migrate/20130919131325_devise_create_admin_users.rb
#  create mode 100644 db/migrate/20130919131326_create_active_admin_comments.rb
#  create mode 100644 db/migrate/20130919131327_add_image_to_posts.rb
#  create mode 100644 db/schema.rb
#  create mode 100644 db/seeds.rb
#  create mode 100644 lib/assets/.keep
#  create mode 100644 lib/tasks/.keep
#  create mode 100644 log/.keep
#  create mode 100644 public/404.html
#  create mode 100644 public/422.html
#  create mode 100644 public/500.html
#  create mode 100644 public/favicon.ico
#  create mode 100644 public/robots.txt
#  create mode 100644 public/uploads/post/image/1/9743636584_5fa50a50a7_b.jpg
#  create mode 100644 public/uploads/post/image/1/thumb_9743636584_5fa50a50a7_b.jpg
#  create mode 100644 public/uploads/post/image/2/9801397956_287be5e41f_c.jpg
#  create mode 100644 public/uploads/post/image/2/thumb_9801397956_287be5e41f_c.jpg
#  create mode 100644 public/uploads/post/image/3/2013-09-13-173710.jpg
#  create mode 100644 public/uploads/post/image/3/thumb_2013-09-13-173710.jpg
#  create mode 100644 public/uploads/post/image/4/9743636584_5fa50a50a7_b.jpg
#  create mode 100644 public/uploads/post/image/4/thumb_9743636584_5fa50a50a7_b.jpg
#  create mode 100644 public/uploads/tmp/1379613910-13035-9410/9743636584_5fa50a50a7_b.jpg
#  create mode 100644 public/uploads/tmp/1379613910-13035-9410/thumb_9743636584_5fa50a50a7_b.jpg
#  create mode 100644 public/uploads/tmp/1379614097-13650-3612/9743636584_5fa50a50a7_b.jpg
#  create mode 100644 public/uploads/tmp/1379614097-13650-3612/thumb_9743636584_5fa50a50a7_b.jpg
#  create mode 100644 public/uploads/tmp/1379619152-27653-2014/9743636584_5fa50a50a7_b.jpg
#  create mode 100644 public/uploads/tmp/1379619152-27653-2014/thumb_9743636584_5fa50a50a7_b.jpg
#  create mode 100644 public/uploads/tmp/1379619300-27653-5113/9743636584_5fa50a50a7_b.jpg
#  create mode 100644 public/uploads/tmp/1379619300-27653-5113/thumb_9743636584_5fa50a50a7_b.jpg
#  create mode 100644 public/uploads/tmp/1379619360-27653-7505/9743636584_5fa50a50a7_b.jpg
#  create mode 100644 public/uploads/tmp/1379619360-27653-7505/thumb_9743636584_5fa50a50a7_b.jpg
#  create mode 100644 test/controllers/.keep
#  create mode 100644 test/controllers/pages_controller_test.rb
#  create mode 100644 test/controllers/posts_controller_test.rb
#  create mode 100644 test/fixtures/.keep
#  create mode 100644 test/fixtures/admin_users.yml
#  create mode 100644 test/fixtures/categories.yml
#  create mode 100644 test/fixtures/pages.yml
#  create mode 100644 test/fixtures/posts.yml
#  create mode 100644 test/helpers/.keep
#  create mode 100644 test/helpers/pages_helper_test.rb
#  create mode 100644 test/helpers/posts_helper_test.rb
#  create mode 100644 test/integration/.keep
#  create mode 100644 test/mailers/.keep
#  create mode 100644 test/models/.keep
#  create mode 100644 test/models/admin_user_test.rb
#  create mode 100644 test/models/category_test.rb
#  create mode 100644 test/models/page_test.rb
#  create mode 100644 test/models/post_test.rb
#  create mode 100644 test/test_helper.rb
#  create mode 100644 vendor/assets/javascripts/.keep
#  create mode 100644 vendor/assets/stylesheets/.keep

# %% [markdown]
# ### $ heroku create

# %% [raw]
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$ heroku create
# Creating immense-cliffs-2933... done, stack is cedar
# http://immense-cliffs-2933.herokuapp.com/ | git@heroku.com:immense-cliffs-2933.git
# Git remote heroku added
#
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$ heroku apps:rename quanta-jump-start-rails
# Renaming immense-cliffs-2933 to quanta-jump-start-rails... done
# http://quanta-jump-start-rails.herokuapp.com/ | git@heroku.com:quanta-jump-start-rails.git
# Git remote heroku updated

# %% [markdown]
# ### $ heroku labs:enable user-env-compile

# %% [raw]
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$ heroku labs:enable user-env-compile
# Enabling user-env-compile for quanta-jump-start-rails... done
# WARNING: This feature is experimental and may change or be removed without notice.
# For more information see: http://devcenter.heroku.com/articles/labs-user-env-compile

# %% [markdown]
# ### $ git push heroku master

# %% [raw]
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$ git push heroku master
# Counting objects: 137, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (127/127), done.
# Writing objects: 100% (137/137), 890.08 KiB | 1.30 MiB/s, done.
# Total 137 (delta 13), reused 0 (delta 0)
#
# -----> Ruby/Rails app detected
# -----> Using Ruby version: ruby-2.0.0
# -----> Installing dependencies using Bundler version 1.3.2
#        Running: bundle install --without development:test --path vendor/bundle --binstubs vendor/bundle/bin --deployment
#        Fetching gem metadata from https://rubygems.org/........
#        Fetching gem metadata from https://rubygems.org/..
#        Fetching git://github.com/plataformatec/devise.git
#        Fetching git://github.com/gregbell/active_admin.git
#        Fetching git://github.com/FriendlyId/friendly_id.git
#        Installing rake (10.1.0)
#        Installing i18n (0.6.5)
#        Installing minitest (4.7.5)
#        Installing multi_json (1.8.0)
#        Installing atomic (1.1.14)
#        Installing thread_safe (0.1.3)
#        Installing tzinfo (0.3.37)
#        Installing activesupport (4.0.0)
#        Installing builder (3.1.4)
#        Installing erubis (2.7.0)
#        Installing rack (1.5.2)
#        Installing rack-test (0.6.2)
#        Installing actionpack (4.0.0)
#        Installing mime-types (1.25)
#        Installing polyglot (0.3.3)
#        Installing treetop (1.4.15)
#        Installing mail (2.5.4)
#        Installing actionmailer (4.0.0)
#        Installing arbre (1.0.1)
#        Installing sass (3.2.10)
#        Installing thor (0.18.1)
#        Installing bourbon (3.1.8)
#        Installing coffee-script-source (1.6.3)
#        Installing execjs (2.0.1)
#        Installing coffee-script (2.2.0)
#        Installing railties (4.0.0)
#        Installing coffee-rails (4.0.0)
#        Installing bcrypt-ruby (3.1.2)
#        Installing orm_adapter (0.4.0)
#        Installing warden (1.2.3)
#        Using devise (3.1.0) from git://github.com/plataformatec/devise.git (at master)
#        Installing formtastic (2.3.0.rc2)
#        Installing has_scope (0.6.0.rc)
#        Installing responders (1.0.0.rc)
#        Installing inherited_resources (1.4.1)
#        Installing jquery-rails (3.0.4)
#        Installing jquery-ui-rails (4.0.4)
#        Installing kaminari (0.14.1)
#        Installing activemodel (4.0.0)
#        Installing activerecord-deprecated_finders (1.0.3)
#        Installing arel (4.0.0)
#        Installing activerecord (4.0.0)
#        Using bundler (1.3.2)
#        Installing hike (1.2.3)
#        Installing tilt (1.4.1)
#        Installing sprockets (2.10.0)
#        Installing sprockets-rails (2.0.0)
#        Installing rails (4.0.0)
#        Installing polyamorous (0.6.4)
#        Installing ransack (1.0.0)
#        Installing sass-rails (4.0.0)
#        Using activeadmin (0.6.0) from git://github.com/gregbell/active_admin.git (at rails4)
#        Installing bootstrap-sass (2.3.2.2)
#        Installing json (1.8.0)
#        Installing carrierwave (0.9.0)
#        Installing excon (0.25.3)
#        Installing formatador (0.2.4)
#        Installing net-ssh (2.7.0)
#        Installing net-scp (1.1.2)
#        Installing mini_portile (0.5.1)
#        Installing nokogiri (1.6.0)
#        Installing ruby-hmac (0.4.0)
#        Installing fog (1.15.0)
#        Using friendly_id (5.0.0.rc2) from git://github.com/FriendlyId/friendly_id.git (at master)
#        Installing jbuilder (1.5.1)
#        Installing turbolinks (1.3.0)
#        Installing jquery-turbolinks (2.0.1)
#        Installing libv8 (3.16.14.3)
#        Installing metamagic (2.0.5)
#        Installing pg (0.17.0)
#        Installing rdoc (3.12.2)
#        Installing ref (1.0.5)
#        Installing rmagick (2.13.2)
#        Installing sdoc (0.3.20)
#        Installing therubyracer (0.12.0)
#        Installing uglifier (2.2.1)
#        Your bundle is complete! It was installed into ./vendor/bundle
#        Post-install message from rdoc:
#        Depending on your version of ruby, you may need to install ruby rdoc/ri data:
#        <= 1.8.6 : unsupported
#        = 1.8.7 : gem install rdoc-data; rdoc-data --install
#        = 1.9.1 : gem install rdoc-data; rdoc-data --install
#        >= 1.9.2 : nothing to do! Yay!
#        Cleaning up the bundler cache.
# -----> Writing config/database.yml to read from DATABASE_URL
# -----> Preparing app for Rails asset pipeline
#        Running: rake assets:precompile
#        I, [2013-09-20T03:11:52.981842 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin-ff6d13b881707ca50d08fa0272c8784e.js
#        I, [2013-09-20T03:12:24.580560 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/application-618cf8b64491a49289e4d18c84ae1a3f.js
#        I, [2013-09-20T03:12:27.629585 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin-c3971878b3585df2d2dd43fcf7ad09a1.css
#        I, [2013-09-20T03:12:40.127464 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/application-93bf4b2d7487d4d6eb32b9725bb91afb.css
#        I, [2013-09-20T03:12:40.141794 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/glyphicons-halflings-white-2fa53df59ca25ee50f59f971c0c9175d.png
#        I, [2013-09-20T03:12:40.143562 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/glyphicons-halflings-4e5b89324f1ac987ddf6835ef51f5fe9.png
#        I, [2013-09-20T03:12:40.146899 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/admin_notes_icon-4ac1d3e758cd242128a20966216a46c0.png
#        I, [2013-09-20T03:12:40.148437 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/datepicker/datepicker-header-bg-03e73b5f1e719d16465c1545f2628e25.png
#        I, [2013-09-20T03:12:40.149775 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/datepicker/datepicker-input-icon-617cb6e5886d6433876592a2f19fdf7a.png
#        I, [2013-09-20T03:12:40.151280 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/datepicker/datepicker-next-link-icon-db49a6ee87baf05f397b779a5162a138.png
#        I, [2013-09-20T03:12:40.152842 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/datepicker/datepicker-nipple-65b51d94aff2c271854cec1c55b11a02.png
#        I, [2013-09-20T03:12:40.154520 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/datepicker/datepicker-prev-link-icon-4f936de276c00632428f459a8504d0f1.png
#        I, [2013-09-20T03:12:40.297691 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/index_list_icons/block_icon-259bef601c7f214b825749dc0798c4cc.svg
#        I, [2013-09-20T03:12:40.302051 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/index_list_icons/blog_icon-8f73cfeba3474d86796329e617136585.svg
#        I, [2013-09-20T03:12:40.306534 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/index_list_icons/grid_icon-1901c30c53086f15768fc53a319f8e5c.svg
#        I, [2013-09-20T03:12:40.312020 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/index_list_icons/table_icon-dc03aed51a579b0981ccfccf46396087.svg
#        I, [2013-09-20T03:12:40.317347 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/loading-87c25f4e23a590b5cbe461f25af1a138.gif
#        I, [2013-09-20T03:12:40.321745 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/nested_menu_arrow-bf84458200437771c8008505579a08b4.gif
#        I, [2013-09-20T03:12:40.325414 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/nested_menu_arrow_dark-a2d1e4d7a88a573a86f71c37b5b47e18.gif
#        I, [2013-09-20T03:12:40.328498 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/orderable-ba64e0e18d92f57b71a86dda1fd16f5b.png
#        I, [2013-09-20T03:12:40.554409 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/application-f5a8c8b11dd6134fa16759ef275b65a3.js
#        I, [2013-09-20T03:12:40.589415 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/pages/application-5b6d3397a971963d2fbb7b0121f4b357.js
#        I, [2013-09-20T03:12:40.790776 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/active_admin/print-5e5388acd0c3d05b4f3bdacf0c563a52.css
#        I, [2013-09-20T03:12:40.797947 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/jquery-ui/animated-overlay-19ad589604d6105e9ffe413a30aadb31.gif
#        I, [2013-09-20T03:12:40.803826 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/jquery-ui/ui-bg_flat_0_aaaaaa_40x100-8336f3b64b15a6de3811e63e9465b6d5.png
#        I, [2013-09-20T03:12:40.809819 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/jquery-ui/ui-bg_flat_75_ffffff_40x100-a17c260bc73d50da2f88f0296c75b3f9.png
#        I, [2013-09-20T03:12:40.816102 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/jquery-ui/ui-bg_glass_55_fbf9ee_1x400-dcb5b697d493c7b787c7162381e6ef74.png
#        I, [2013-09-20T03:12:40.822705 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/jquery-ui/ui-bg_glass_65_ffffff_1x400-7ae4ff0cb55657d98ec8920ec905ec1e.png
#        I, [2013-09-20T03:12:40.829534 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/jquery-ui/ui-bg_glass_75_dadada_1x400-5ede149cc759e26b83734ce72cfa6c18.png
#        I, [2013-09-20T03:12:40.836658 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/jquery-ui/ui-bg_glass_75_e6e6e6_1x400-a6f83694d2bf6a64340fd53bd585270d.png
#        I, [2013-09-20T03:12:40.843283 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/jquery-ui/ui-bg_glass_95_fef1ec_1x400-88438eace1de38adc245321ab95259a0.png
#        I, [2013-09-20T03:12:40.850527 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/jquery-ui/ui-bg_highlight-soft_75_cccccc_1x100-a45d51579bf82a5b02b940d86645be1e.png
#        I, [2013-09-20T03:12:40.858002 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/jquery-ui/ui-icons_222222_256x240-29c3cd52ace47e8aa26068699cba6281.png
#        I, [2013-09-20T03:12:40.865173 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/jquery-ui/ui-icons_2e83ff_256x240-1183af3462270425b028095e5d915a80.png
#        I, [2013-09-20T03:12:40.872458 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/jquery-ui/ui-icons_454545_256x240-9d5e7fa056ec8fc9174d77c6d0b74712.png
#        I, [2013-09-20T03:12:40.879630 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/jquery-ui/ui-icons_888888_256x240-c427a0ec883978acaae748d6e4d1954a.png
#        I, [2013-09-20T03:12:40.886720 #2907]  INFO -- : Writing /tmp/build_8a30c1a3-e388-42ea-9520-4bb4b68d3155/public/assets/jquery-ui/ui-icons_cd0a0a_256x240-161d4e6cfcecc852ada1a8409f5f7550.png
#        Asset precompilation completed (68.86s)
#        Cleaning assets
# -----> WARNINGS:
#        Include 'rails_12factor' gem to enable all platform features
#        See https://devcenter.heroku.com/articles/rails-integration-gems for more information.
#
#        You have not declared a Ruby version in your Gemfile.
#        To set your Ruby version add this line to your Gemfile:
#        ruby '2.0.0'
#        # See https://devcenter.heroku.com/articles/ruby-versions for more information."
# -----> Discovering process types
#        Procfile declares types      -> (none)
#        Default types for Ruby/Rails -> console, rake, web, worker
#
# -----> Compiled slug size: 76.9MB
# -----> Launching... done, v5
#        http://quanta-jump-start-rails.herokuapp.com deployed to Heroku
#
# To git@heroku.com:quanta-jump-start-rails.git
#  * [new branch]      master -> master

# %% [markdown]
# ### $ heroku run rake db:migrate

# %% [raw]
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$ heroku run rake db:migrate
# Running `rake db:migrate` attached to terminal... up, run.3271
# ==  CreatePages: migrating ====================================================
# -- create_table(:pages)
#    -> 0.0322s
# ==  CreatePages: migrated (0.0326s) ===========================================
#
# ==  AddSlugToPages: migrating =================================================
# -- add_column(:pages, :slug, :string)
#    -> 0.0440s
# ==  AddSlugToPages: migrated (0.0443s) ========================================
#
# ==  CreateCategories: migrating ===============================================
# -- create_table(:categories)
#    -> 0.0252s
# ==  CreateCategories: migrated (0.0254s) ======================================
#
# ==  CreatePosts: migrating ====================================================
# -- create_table(:posts)
#    -> 0.1550s
# ==  CreatePosts: migrated (0.1555s) ===========================================
#
# ==  DeviseCreateAdminUsers: migrating =========================================
# -- create_table(:admin_users)
#    -> 0.0905s
# -- add_index(:admin_users, :email, {:unique=>true})
#    -> 0.0699s
# -- add_index(:admin_users, :reset_password_token, {:unique=>true})
#    -> 0.1019s
# ==  DeviseCreateAdminUsers: migrated (0.2632s) ================================
#
# ==  CreateActiveAdminComments: migrating ======================================
# -- create_table(:active_admin_comments)
#    -> 0.0186s
# -- add_index(:active_admin_comments, [:namespace])
#    -> 0.1102s
# -- add_index(:active_admin_comments, [:author_type, :author_id])
#    -> 0.1483s
# -- add_index(:active_admin_comments, [:resource_type, :resource_id])
#    -> 0.1932s
# ==  CreateActiveAdminComments: migrated (0.4711s) =============================
#
# ==  AddImageToPosts: migrating ================================================
# -- add_column(:posts, :image, :string)
#    -> 0.0640s
# ==  AddImageToPosts: migrated (0.0642s) =======================================

# %% [markdown]
# ## Fix to add ruby '2.0.0' explicitely in Gemfile and republish to Heroku

# %% [markdown]
# ### $ git add .

# %% [markdown]
# ### Fix user name and email for heroku git

# %% [raw]
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$ git commit -m "add ruby 2.0.0 in Gemfile"
# [master 631cc27] add ruby 2.0.0 in Gemfile
#  Committer: Quan Nguyen <quan@quan-VirtualBox.(none)>
# Your name and email address were configured automatically based
# on your username and hostname. Please check that they are accurate.
# You can suppress this message by setting them explicitly:
#
#     git config --global user.name "Your Name"
#     git config --global user.email you@example.com
#
# After doing this, you may fix the identity used for this commit with:
#
#     git commit --amend --reset-author
#
#  1 file changed, 1 insertion(+)
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$ git config --global user.name "Quan Nguyen"
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$ git config --global user.email mr.quan.nguyen@gmail.com
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$ git commit --amend --reset-author
# [master cceef7b] add ruby 2.0.0 in Gemfile
#  1 file changed, 1 insertion(+)

# %% [markdown]
# ### $ git commit -m "add ruby 2.0.0 in Gemfile"

# %% [markdown]
# ### $ git push heroku master

# %% [raw]
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$ git push heroku master
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 317 bytes, done.
# Total 3 (delta 2), reused 0 (delta 0)
#
# -----> Ruby/Rails app detected
# -----> Using Ruby version: ruby-2.0.0
# -----> Installing dependencies using Bundler version 1.3.2
#        Running: bundle install --without development:test --path vendor/bundle --binstubs vendor/bundle/bin --deployment
#        Using rake (10.1.0)
#        Using i18n (0.6.5)
#        Using minitest (4.7.5)
#        Using multi_json (1.8.0)
#        Using atomic (1.1.14)
#        Using thread_safe (0.1.3)
#        Using tzinfo (0.3.37)
#        Using activesupport (4.0.0)
#        Using builder (3.1.4)
#        Using erubis (2.7.0)
#        Using rack (1.5.2)
#        Using rack-test (0.6.2)
#        Using actionpack (4.0.0)
#        Using mime-types (1.25)
#        Using polyglot (0.3.3)
#        Using treetop (1.4.15)
#        Using mail (2.5.4)
#        Using actionmailer (4.0.0)
#        Using arbre (1.0.1)
#        Using sass (3.2.10)
#        Using thor (0.18.1)
#        Using bourbon (3.1.8)
#        Using coffee-script-source (1.6.3)
#        Using execjs (2.0.1)
#        Using coffee-script (2.2.0)
#        Using railties (4.0.0)
#        Using coffee-rails (4.0.0)
#        Using bcrypt-ruby (3.1.2)
#        Using orm_adapter (0.4.0)
#        Using warden (1.2.3)
#        Using devise (3.1.0) from git://github.com/plataformatec/devise.git (at master)
#        Using formtastic (2.3.0.rc2)
#        Using has_scope (0.6.0.rc)
#        Using responders (1.0.0.rc)
#        Using inherited_resources (1.4.1)
#        Using jquery-rails (3.0.4)
#        Using jquery-ui-rails (4.0.4)
#        Using kaminari (0.14.1)
#        Using activemodel (4.0.0)
#        Using activerecord-deprecated_finders (1.0.3)
#        Using arel (4.0.0)
#        Using activerecord (4.0.0)
#        Using bundler (1.3.2)
#        Using hike (1.2.3)
#        Using tilt (1.4.1)
#        Using sprockets (2.10.0)
#        Using sprockets-rails (2.0.0)
#        Using rails (4.0.0)
#        Using polyamorous (0.6.4)
#        Using ransack (1.0.0)
#        Using sass-rails (4.0.0)
#        Using activeadmin (0.6.0) from git://github.com/gregbell/active_admin.git (at rails4)
#        Using bootstrap-sass (2.3.2.2)
#        Using json (1.8.0)
#        Using carrierwave (0.9.0)
#        Using excon (0.25.3)
#        Using formatador (0.2.4)
#        Using net-ssh (2.7.0)
#        Using net-scp (1.1.2)
#        Using mini_portile (0.5.1)
#        Using nokogiri (1.6.0)
#        Using ruby-hmac (0.4.0)
#        Using fog (1.15.0)
#        Using friendly_id (5.0.0.rc2) from git://github.com/FriendlyId/friendly_id.git (at master)
#        Using jbuilder (1.5.1)
#        Using turbolinks (1.3.0)
#        Using jquery-turbolinks (2.0.1)
#        Using libv8 (3.16.14.3)
#        Using metamagic (2.0.5)
#        Using pg (0.17.0)
#        Using rdoc (3.12.2)
#        Using ref (1.0.5)
#        Using rmagick (2.13.2)
#        Using sdoc (0.3.20)
#        Using therubyracer (0.12.0)
#        Using uglifier (2.2.1)
#        Your bundle is complete! It was installed into ./vendor/bundle
#        Cleaning up the bundler cache.
# -----> Writing config/database.yml to read from DATABASE_URL
# -----> Preparing app for Rails asset pipeline
#        Running: rake assets:precompile
#        Asset precompilation completed (85.02s)
#        Cleaning assets
# -----> WARNINGS:
#        Include 'rails_12factor' gem to enable all platform features
#        See https://devcenter.heroku.com/articles/rails-integration-gems for more information.
# -----> Discovering process types
#        Procfile declares types      -> (none)
#        Default types for Ruby/Rails -> console, rake, web, worker
#
# -----> Compiled slug size: 76.9MB
# -----> Launching... done, v6
#        http://quanta-jump-start-rails.herokuapp.com deployed to Heroku
#
# To git@heroku.com:quanta-jump-start-rails.git
#    2c938a3..cceef7b  master -> master
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$

# %% [markdown]
# ### There is a bug that app deployed on heroku is mising all the stylesheets. The fix is to add "config.assets.compile = true" in config/environments/production.rb"

# %% [raw]
#   config.assets.compile = true

# %% [raw]
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$ git add .
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$ git commit -m "after config.assets.compile set to true"
# [master 7d069e7] after config.assets.compile set to true
#  1 file changed, 1 insertion(+), 1 deletion(-)
# quan@quan-VirtualBox:~/rails_projects/jumpstartrails$ git push heroku masterCounting objects: 9, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 499 bytes, done.
# Total 5 (delta 3), reused 0 (delta 0)
#
# -----> Ruby/Rails app detected
# -----> Using Ruby version: ruby-2.0.0
# -----> Installing dependencies using Bundler version 1.3.2
#        Running: bundle install --without development:test --path vendor/bundle --binstubs vendor/bundle/bin --deployment
#        Using rake (10.1.0)
#        Using i18n (0.6.5)
#        Using minitest (4.7.5)
#        Using multi_json (1.8.0)
#        Using atomic (1.1.14)
#        Using thread_safe (0.1.3)
#        Using tzinfo (0.3.37)
#        Using activesupport (4.0.0)
#        Using builder (3.1.4)
#        Using erubis (2.7.0)
#        Using rack (1.5.2)
#        Using rack-test (0.6.2)
#        Using actionpack (4.0.0)
#        Using mime-types (1.25)
#        Using polyglot (0.3.3)
#        Using treetop (1.4.15)
#        Using mail (2.5.4)
#        Using actionmailer (4.0.0)
#        Using arbre (1.0.1)
#        Using sass (3.2.10)
#        Using thor (0.18.1)
#        Using bourbon (3.1.8)
#        Using coffee-script-source (1.6.3)
#        Using execjs (2.0.1)
#        Using coffee-script (2.2.0)
#        Using railties (4.0.0)
#        Using coffee-rails (4.0.0)
#        Using bcrypt-ruby (3.1.2)
#        Using orm_adapter (0.4.0)
#        Using warden (1.2.3)
#        Using devise (3.1.0) from git://github.com/plataformatec/devise.git (at master)
#        Using formtastic (2.3.0.rc2)
#        Using has_scope (0.6.0.rc)
#        Using responders (1.0.0.rc)
#        Using inherited_resources (1.4.1)
#        Using jquery-rails (3.0.4)
#        Using jquery-ui-rails (4.0.4)
#        Using kaminari (0.14.1)
#        Using activemodel (4.0.0)
#        Using activerecord-deprecated_finders (1.0.3)
#        Using arel (4.0.0)
#        Using activerecord (4.0.0)
#        Using bundler (1.3.2)
#        Using hike (1.2.3)
#        Using tilt (1.4.1)
#        Using sprockets (2.10.0)
#        Using sprockets-rails (2.0.0)
#        Using rails (4.0.0)
#        Using polyamorous (0.6.4)
#        Using ransack (1.0.0)
#        Using sass-rails (4.0.0)
#        Using activeadmin (0.6.0) from git://github.com/gregbell/active_admin.git (at rails4)
#        Using bootstrap-sass (2.3.2.2)
#        Using json (1.8.0)
#        Using carrierwave (0.9.0)
#        Using excon (0.25.3)
#        Using formatador (0.2.4)
#        Using net-ssh (2.7.0)
#        Using net-scp (1.1.2)
#        Using mini_portile (0.5.1)
#        Using nokogiri (1.6.0)
#        Using ruby-hmac (0.4.0)
#        Using fog (1.15.0)
#        Using friendly_id (5.0.0.rc2) from git://github.com/FriendlyId/friendly_id.git (at master)
#        Using jbuilder (1.5.1)
#        Using turbolinks (1.3.0)
#        Using jquery-turbolinks (2.0.1)
#        Using libv8 (3.16.14.3)
#        Using metamagic (2.0.5)
#        Using pg (0.17.0)
#        Using rdoc (3.12.2)
#        Using ref (1.0.5)
#        Using rmagick (2.13.2)
#        Using sdoc (0.3.20)
#        Using therubyracer (0.12.0)
#        Using uglifier (2.2.1)
#        Your bundle is complete! It was installed into ./vendor/bundle
#        Cleaning up the bundler cache.
# -----> Writing config/database.yml to read from DATABASE_URL
# -----> Preparing app for Rails asset pipeline
#        Detected manifest file, assuming assets were compiled locally
# -----> WARNINGS:
#        Include 'rails_12factor' gem to enable all platform features
#        See https://devcenter.heroku.com/articles/rails-integration-gems for more information.
# -----> Discovering process types
#        Procfile declares types      -> (none)
#        Default types for Ruby/Rails -> console, rake, web, worker
#
# -----> Compiled slug size: 76.0MB
# -----> Launching... done, v8
#        http://quanta-jump-start-rails.herokuapp.com deployed to Heroku
#
# To git@heroku.com:quanta-jump-start-rails.git
#    9a4ee89..7d069e7  master -> master
